# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winedataset.csv')
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# 5        1    14.20        1.76  2.45               15.2        112
# 6        1    14.39        1.87  2.45               14.6         96
# 7        1    14.06        2.15  2.61               17.6        121
# 8        1    14.83        1.64  2.17               14.0         97
# 9        1    13.86        1.35  2.27               16.0         98
# 10       1    14.10        2.16  2.30               18.0        105
# 11       1    14.12        1.48  2.32               16.8         95
# 12       1    13.75        1.73  2.41               16.0         89
# ...

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
# Class                   178 non-null int64
# Alcohol                 178 non-null float64
# Malic acid              178 non-null float64
# Ash                     178 non-null float64
# Alcalinity of ash       178 non-null float64
# Magnesium               178 non-null int64
# Total phenols           178 non-null float64
# Flavanoids              178 non-null float64
# Nonflavanoid phenols    178 non-null float64
# Proanthocyanins         178 non-null float64
# Color intensity         178 non-null float64
# Hue                     178 non-null float64
# diluted wines           178 non-null float64
# Proline                 178 non-null int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.Magnesium.unique()
# Out:
# array([127, 100, 101, 113, 118, 112,  96, 121,  97,  98, 105,  95,  89,
#         91, 102, 120, 115, 108, 116, 126, 124,  93,  94, 107, 106, 104,
#        132, 110, 128, 117,  90, 103, 111,  92,  88,  87,  78, 151,  86,
#        139, 136,  85,  99,  84,  70,  81,  80, 162, 134, 119,  82, 122,
#        123], dtype=int64)

# %%
dfcor=df.corr()
sns.heatmap(dfcor)

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(12,5*12))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
#Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.21394365, 1.51861254, 0.5622498 , ..., 0.36217728, 1.84791957,
#         1.01300893],
#        [1.21394365, 0.24628963, 0.49941338, ..., 0.40605066, 1.1134493 ,
#         0.96524152],
#        [1.21394365, 0.19687903, 0.02123125, ..., 0.31830389, 0.78858745,
#         1.39514818],
#        ...,
#        [1.37386437, 0.33275817, 1.74474449, ..., 1.61212515, 1.48544548,
#         0.28057537],
#        [1.37386437, 0.20923168, 0.22769377, ..., 1.56825176, 1.40069891,
#         0.29649784],
#        [1.37386437, 1.39508604, 1.58316512, ..., 1.52437837, 1.42894777,
#         0.59516041]])

# %%
threshold=3

# %%
print(np.where(z>3))
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (168, 14)

# %%
df.shape
# Out:
# (178, 14)

# %%
collist1=df_new.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(12,5*12))
for i in range(0,len(collist1)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df_new[collist1[i]],color='green',orient='v')
    plt.tight_layout()

# %%
dfcor1=df_new.corr()
sns.heatmap(dfcor1)

# %%
df_x=df.drop(columns=["Class"])
df_y=df[["Class"]]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
knr=KNeighborsRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor())])
parameters = {"knr__n_neighbors":range(2,30)}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(df_x, df_y)
clf.best_params_
# Out:
# {'knr__n_neighbors': 15}

# %%
pipeline_knr=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor(n_neighbors=15))])
#knr=KNeighborsRegressor(n_neighbors=29)
maxr2_score(pipeline_knr,df_x,df_y)
# Out:
# r2 score corresponding to  42  is  0.9623280423280423
# r2 score corresponding to  43  is  0.9214814814814815
# r2 score corresponding to  44  is  0.8743988684582744
# r2 score corresponding to  45  is  0.9682
# r2 score corresponding to  46  is  0.9358762886597938
# r2 score corresponding to  47  is  0.9525925925925925
# r2 score corresponding to  48  is  0.9635643564356435
# r2 score corresponding to  49  is  0.9522222222222222
# r2 score corresponding to  50  is  0.9657731958762886
# r2 score corresponding to  51  is  0.9394152046783626
# r2 score corresponding to  52  is  0.9331645569620253
# r2 score corresponding to  53  is  0.9260913705583756
# r2 score corresponding to  54  is  0.9390286425902864
# r2 score corresponding to  55  is  0.9656361149110807
# r2 score corresponding to  56  is  0.9159259259259259
# r2 score corresponding to  57  is  0.984549356223176
# r2 score corresponding to  58  is  0.8991111111111111
# r2 score corresponding to  59  is  0.9813125695216908
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = 81,test_size=0.20)
clf.fit(df_x, df_y)
y_pred = clf.predict(x_test)

# %%
print("MSE is: ",mean_squared_error(y_test,y_pred))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# MSE is:  0.009382716049382718
# r2_score is:  0.9863524130190797

# %%
from sklearn.externals import joblib
joblib.dump(clf, 'lg_winedataset.pkl')
# Out:
# ['lg_winedataset.pkl']
